# %%
import pandas as pd

# %%
df =  pd.read_csv("empsal_part_buck.csv")

# %%
df
# Out:
#    empid          empname          city    sal  age         dob         dept
# 0   E001       John Adams      New York  73400   29  1996-08-12      Finance
# 1   E002     Sarah Miller   Los Angeles  81200   34  1991-04-23           HR
# 2   E003    Michael Brown       Chicago  65400   41  1984-02-11  Engineering
# 3   E004      Emily Davis       Houston  58900   27  1998-06-04    Marketing
# 4   E005    Daniel Wilson       Phoenix  91300   45  1980-09-19           IT
# ..   ...              ...           ...    ...  ...         ...          ...
# 95  E096      Elise Hardy    Des Moines  58300   24  2001-05-30           HR
# 96  E097      Camden Bush       Modesto  72800   32  1993-04-03  Engineering
# 97  E098  Madeline Abbott  Fayetteville  75600   34  1991-01-28    Marketing
# 98  E099     Robert Drake    Shreveport  69100   30  1995-06-09      Finance
# 99  E100    Aurora Briggs         Akron  82300   38  1987-10-01           IT
#
# [100 rows x 7 columns]

# %%
df.shape
# Out:
# (100, 7)

# %%
df.dtypes
# Out:
# empid      object
# empname    object
# city       object
# sal         int64
# age         int64
# dob        object
# dept       object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   empid    100 non-null    object
#  1   empname  100 non-null    object
#  2   city     100 non-null    object
#  3   sal      100 non-null    int64
#  4   age      100 non-null    int64
#  5   dob      100 non-null    object
#  6   dept     100 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 5.6+ KB

# %%
df
# Out:
#    empid          empname          city    sal  age         dob         dept
# 0   E001       John Adams      New York  73400   29  1996-08-12      Finance
# 1   E002     Sarah Miller   Los Angeles  81200   34  1991-04-23           HR
# 2   E003    Michael Brown       Chicago  65400   41  1984-02-11  Engineering
# 3   E004      Emily Davis       Houston  58900   27  1998-06-04    Marketing
# 4   E005    Daniel Wilson       Phoenix  91300   45  1980-09-19           IT
# ..   ...              ...           ...    ...  ...         ...          ...
# 95  E096      Elise Hardy    Des Moines  58300   24  2001-05-30           HR
# 96  E097      Camden Bush       Modesto  72800   32  1993-04-03  Engineering
# 97  E098  Madeline Abbott  Fayetteville  75600   34  1991-01-28    Marketing
# 98  E099     Robert Drake    Shreveport  69100   30  1995-06-09      Finance
# 99  E100    Aurora Briggs         Akron  82300   38  1987-10-01           IT
#
# [100 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['empid', 'empname', 'city', 'sal', 'age', 'dob', 'dept'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df
# Out:
#    empid          empname          city    sal  age         dob         dept
# 0   E001       John Adams      New York  73400   29  1996-08-12      Finance
# 1   E002     Sarah Miller   Los Angeles  81200   34  1991-04-23           HR
# 2   E003    Michael Brown       Chicago  65400   41  1984-02-11  Engineering
# 3   E004      Emily Davis       Houston  58900   27  1998-06-04    Marketing
# 4   E005    Daniel Wilson       Phoenix  91300   45  1980-09-19           IT
# ..   ...              ...           ...    ...  ...         ...          ...
# 95  E096      Elise Hardy    Des Moines  58300   24  2001-05-30           HR
# 96  E097      Camden Bush       Modesto  72800   32  1993-04-03  Engineering
# 97  E098  Madeline Abbott  Fayetteville  75600   34  1991-01-28    Marketing
# 98  E099     Robert Drake    Shreveport  69100   30  1995-06-09      Finance
# 99  E100    Aurora Briggs         Akron  82300   38  1987-10-01           IT
#
# [100 rows x 7 columns]

# %%
type(df['empname'])
# Out:
# pandas.core.series.Series

# %%
df.get('dsfsdfsdf','no col present')
# Out:
# 'no col present'

# %%
df.empname
# Out:
# 0          John Adams
# 1        Sarah Miller
# 2       Michael Brown
# 3         Emily Davis
# 4       Daniel Wilson
#            ...
# 95        Elise Hardy
# 96        Camden Bush
# 97    Madeline Abbott
# 98       Robert Drake
# 99      Aurora Briggs
# Name: empname, Length: 100, dtype: object

# %%
df[['empname','age','city']]
# Out:
#             empname  age          city
# 0        John Adams   29      New York
# 1      Sarah Miller   34   Los Angeles
# 2     Michael Brown   41       Chicago
# 3       Emily Davis   27       Houston
# 4     Daniel Wilson   45       Phoenix
# ..              ...  ...           ...
# 95      Elise Hardy   24    Des Moines
# 96      Camden Bush   32       Modesto
# 97  Madeline Abbott   34  Fayetteville
# 98     Robert Drake   30    Shreveport
# 99    Aurora Briggs   38         Akron
#
# [100 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['empid', 'empname', 'city', 'sal', 'age', 'dob', 'dept'], dtype='object')

# %%
df[[col for col in df.columns if col.startswith('emp')]]
# Out:
#    empid          empname
# 0   E001       John Adams
# 1   E002     Sarah Miller
# 2   E003    Michael Brown
# 3   E004      Emily Davis
# 4   E005    Daniel Wilson
# ..   ...              ...
# 95  E096      Elise Hardy
# 96  E097      Camden Bush
# 97  E098  Madeline Abbott
# 98  E099     Robert Drake
# 99  E100    Aurora Briggs
#
# [100 rows x 2 columns]

# %%
#rename col

# %%
df.rename({"city":"empcity"},axis=1,inplace=True)

# %%
df
# Out:
#    empid          empname          city    sal  age         dob         dept
# 0   E001       John Adams      New York  73400   29  1996-08-12      Finance
# 1   E002     Sarah Miller   Los Angeles  81200   34  1991-04-23           HR
# 2   E003    Michael Brown       Chicago  65400   41  1984-02-11  Engineering
# 3   E004      Emily Davis       Houston  58900   27  1998-06-04    Marketing
# 4   E005    Daniel Wilson       Phoenix  91300   45  1980-09-19           IT
# ..   ...              ...           ...    ...  ...         ...          ...
# 95  E096      Elise Hardy    Des Moines  58300   24  2001-05-30           HR
# 96  E097      Camden Bush       Modesto  72800   32  1993-04-03  Engineering
# 97  E098  Madeline Abbott  Fayetteville  75600   34  1991-01-28    Marketing
# 98  E099     Robert Drake    Shreveport  69100   30  1995-06-09      Finance
# 99  E100    Aurora Briggs         Akron  82300   38  1987-10-01           IT
#
# [100 rows x 7 columns]

# %%
df
# Out:
#    empid          empname       empcity    sal  age         dob         dept
# 0   E001       John Adams      New York  73400   29  1996-08-12      Finance
# 1   E002     Sarah Miller   Los Angeles  81200   34  1991-04-23           HR
# 2   E003    Michael Brown       Chicago  65400   41  1984-02-11  Engineering
# 3   E004      Emily Davis       Houston  58900   27  1998-06-04    Marketing
# 4   E005    Daniel Wilson       Phoenix  91300   45  1980-09-19           IT
# ..   ...              ...           ...    ...  ...         ...          ...
# 95  E096      Elise Hardy    Des Moines  58300   24  2001-05-30           HR
# 96  E097      Camden Bush       Modesto  72800   32  1993-04-03  Engineering
# 97  E098  Madeline Abbott  Fayetteville  75600   34  1991-01-28    Marketing
# 98  E099     Robert Drake    Shreveport  69100   30  1995-06-09      Finance
# 99  E100    Aurora Briggs         Akron  82300   38  1987-10-01           IT
#
# [100 rows x 7 columns]

# %%
df.rename({"sal":"empsal","age":"empage"},axis=1,inplace=True)

# %%
df
# Out:
#    empid          empname       empcity  empsal  empage         dob  \
# 0   E001       John Adams      New York   73400      29  1996-08-12
# 1   E002     Sarah Miller   Los Angeles   81200      34  1991-04-23
# 2   E003    Michael Brown       Chicago   65400      41  1984-02-11
# 3   E004      Emily Davis       Houston   58900      27  1998-06-04
# 4   E005    Daniel Wilson       Phoenix   91300      45  1980-09-19
# ..   ...              ...           ...     ...     ...         ...
# 95  E096      Elise Hardy    Des Moines   58300      24  2001-05-30
# 96  E097      Camden Bush       Modesto   72800      32  1993-04-03
# 97  E098  Madeline Abbott  Fayetteville   75600      34  1991-01-28
# 98  E099     Robert Drake    Shreveport   69100      30  1995-06-09
# 99  E100    Aurora Briggs         Akron   82300      38  1987-10-01
#
#            dept
# 0       Finance
# 1            HR
# 2   Engineering
# 3     Marketing
# 4            IT
# ..          ...
# 95           HR
# ...

# %%
df.columns = [col.upper() for col in df.columns]

# %%
df
# Out:
#    EMPID          EMPNAME       EMPCITY  EMPSAL  EMPAGE         DOB  \
# 0   E001       John Adams      New York   73400      29  1996-08-12
# 1   E002     Sarah Miller   Los Angeles   81200      34  1991-04-23
# 2   E003    Michael Brown       Chicago   65400      41  1984-02-11
# 3   E004      Emily Davis       Houston   58900      27  1998-06-04
# 4   E005    Daniel Wilson       Phoenix   91300      45  1980-09-19
# ..   ...              ...           ...     ...     ...         ...
# 95  E096      Elise Hardy    Des Moines   58300      24  2001-05-30
# 96  E097      Camden Bush       Modesto   72800      32  1993-04-03
# 97  E098  Madeline Abbott  Fayetteville   75600      34  1991-01-28
# 98  E099     Robert Drake    Shreveport   69100      30  1995-06-09
# 99  E100    Aurora Briggs         Akron   82300      38  1987-10-01
#
#            DEPT
# 0       Finance
# 1            HR
# 2   Engineering
# 3     Marketing
# 4            IT
# ..          ...
# 95           HR
# ...

# %%
df.columns = [col.lower() for col in df.columns]

# %%
df.columns = ['temp_{}'.format(col) for col in df.columns]

# %%
df
# Out:
#    temp_temp_empid_ temp_temp_empname_ temp_temp_empcity_  temp_temp_empsal_  \
# 0              E001         John Adams           New York              73400
# 1              E002       Sarah Miller        Los Angeles              81200
# 2              E003      Michael Brown            Chicago              65400
# 3              E004        Emily Davis            Houston              58900
# 4              E005      Daniel Wilson            Phoenix              91300
# ..              ...                ...                ...                ...
# 95             E096        Elise Hardy         Des Moines              58300
# 96             E097        Camden Bush            Modesto              72800
# 97             E098    Madeline Abbott       Fayetteville              75600
# 98             E099       Robert Drake         Shreveport              69100
# 99             E100      Aurora Briggs              Akron              82300
#
# ...

# %%
df.columns = [col.split('_')[-2] for col in df.columns]

# %%
df.rename({0:"zero"})
# Out:
#      empid          empname       empcity  empsal  empage         dob  \
# zero  E001       John Adams      New York   73400      29  1996-08-12
# 1     E002     Sarah Miller   Los Angeles   81200      34  1991-04-23
# 2     E003    Michael Brown       Chicago   65400      41  1984-02-11
# 3     E004      Emily Davis       Houston   58900      27  1998-06-04
# 4     E005    Daniel Wilson       Phoenix   91300      45  1980-09-19
# ...    ...              ...           ...     ...     ...         ...
# 95    E096      Elise Hardy    Des Moines   58300      24  2001-05-30
# 96    E097      Camden Bush       Modesto   72800      32  1993-04-03
# 97    E098  Madeline Abbott  Fayetteville   75600      34  1991-01-28
# 98    E099     Robert Drake    Shreveport   69100      30  1995-06-09
# 99    E100    Aurora Briggs         Akron   82300      38  1987-10-01
#
#              dept
# zero      Finance
# 1              HR
# 2     Engineering
# 3       Marketing
# 4              IT
# ...

# %%
df["updated_on"]= '03.06.2026'

# %%
df1 = df.drop("dob",axis=1)

# %%
df.drop(columns=['empid','empname','empcity'])
# Out:
#     empsal  empage         dob         dept  updated_on
# 0    73400      29  1996-08-12      Finance  03.06.2026
# 1    81200      34  1991-04-23           HR  03.06.2026
# 2    65400      41  1984-02-11  Engineering  03.06.2026
# 3    58900      27  1998-06-04    Marketing  03.06.2026
# 4    91300      45  1980-09-19           IT  03.06.2026
# ..     ...     ...         ...          ...         ...
# 95   58300      24  2001-05-30           HR  03.06.2026
# 96   72800      32  1993-04-03  Engineering  03.06.2026
# 97   75600      34  1991-01-28    Marketing  03.06.2026
# 98   69100      30  1995-06-09      Finance  03.06.2026
# 99   82300      38  1987-10-01           IT  03.06.2026
#
# [100 rows x 5 columns]

# %%
df.drop([0,2,5])
# Out:
#    empid          empname       empcity  empsal  empage         dob  \
# 1   E002     Sarah Miller   Los Angeles   81200      34  1991-04-23
# 3   E004      Emily Davis       Houston   58900      27  1998-06-04
# 4   E005    Daniel Wilson       Phoenix   91300      45  1980-09-19
# 6   E007      Matthew Lee   San Antonio   62300      26  1999-03-14
# 7   E008    Amanda Taylor     San Diego   84500      38  1987-05-22
# ..   ...              ...           ...     ...     ...         ...
# 95  E096      Elise Hardy    Des Moines   58300      24  2001-05-30
# 96  E097      Camden Bush       Modesto   72800      32  1993-04-03
# 97  E098  Madeline Abbott  Fayetteville   75600      34  1991-01-28
# 98  E099     Robert Drake    Shreveport   69100      30  1995-06-09
# 99  E100    Aurora Briggs         Akron   82300      38  1987-10-01
#
#            dept  updated_on
# 1            HR  03.06.2026
# 3     Marketing  03.06.2026
# 4            IT  03.06.2026
# 6   Engineering  03.06.2026
# ...

# %%
empdata = [[101,'Keshav','Pune'],
[102,'Amit','Mumbai'],
[101,'Tushar','Chennai'],
[102,'Amit','Mumbai']]

# %%
df3 = pd.DataFrame(empdata,columns=['id','name','city'])

# %%
df3
# Out:
#     id    name     city
# 0  101  Keshav     Pune
# 1  102    Amit   Mumbai
# 2  101  Tushar  Chennai
# 3  102    Amit   Mumbai

# %%
df3.drop_duplicates(inplace=True)

# %%
df3.loc[0,'city'] = 'mumbai'

# %%
df3.loc[0:1,"id":"city"]
# Out:
#     id    name    city
# 0  101  Keshav  mumbai
# 1  102    Amit  Mumbai

# %%
df3.loc[[0,2],["id","city"]]
# Out:
#     id     city
# 0  101   mumbai
# 2  101  Chennai

# %%
df3.loc[0:2,"name":"city"]
# Out:
#      name     city
# 0  Keshav   mumbai
# 1    Amit   Mumbai
# 2  Tushar  Chennai

# %%
iloc -  intger based location

# %%
df3
# Out:
#     id    name     city
# 0  101  Keshav   mumbai
# 1  102    Amit   Mumbai
# 2  101  Tushar  Chennai

# %%
df = pd.read_html("COVID-19 pandemic by country and territory - Wikipedia.html")

# %%
df = df[12]

# %%
df
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239  ^ Countries which do not report data for a col...
#
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                                      North Macedonia
# ...

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df
# Out:
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                                      North Macedonia
# 4                               Bosnia and Herzegovina
# ..                                                 ...
# 235                                   Pitcairn Islands
# 236                                            Tokelau
# 237                                        North Korea
# 238                                       Turkmenistan
# 239  ^ Countries which do not report data for a col...
#
#                                       Deaths / million  \
# 0                                                  894
# 1                                                 6603
# 2                                                 5681
# 3                                                 5429
# ...

# %%
df.loc
